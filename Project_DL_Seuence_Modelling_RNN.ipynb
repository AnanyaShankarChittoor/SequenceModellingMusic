# %% [markdown]
# 1. **Installation of Libraries:**
#    - `!pip install scikit-learn tensorflow music21`:
#      - Installs the `scikit-learn` library for machine learning tasks.
#      - Installs the `tensorflow` library, which is used for building and training deep learning models.
#      - Installs the `music21` library, a toolkit for computer-aided musicology and symbolic music processing.
#
# 2. **Importing Libraries:**
#    - `import zipfile`:
#      - Used for reading and writing ZIP files.
#    - `import os`:
#      - Provides a way of using operating system-dependent functionality, such as reading or writing to the file system.
#    - `from sklearn.model_selection import train_test_split`:
#      - A function from `scikit-learn` that splits arrays or matrices into random train and test subsets.
#    - `import json`:
#      - Used to parse and create JSON data.
#    - `import music21 as m21`:
#      - Imports the `music21` library under the alias `m21`, which is useful for working with symbolic music data.
#    - `import numpy as np`:
#      - Imports the `numpy` library under the alias `np`, which is used for numerical operations, especially with arrays.
#    - `from tensorflow import keras`:
#      - Imports the `keras` module from `tensorflow`, a high-level API used to build and train neural networks.
#    - `import random`:
#      - Used to generate random numbers.
#    - `import pickle`:
#      - A module used for serializing and deserializing Python objects (for example, saving a model to disk).
#    - `import matplotlib.pyplot as plt`:
#      - Used for creating visualizations, such as plots and charts.
#
# 3. **Explanation of Potential Workflow:**
#    - **Music Processing:**
#      - With `music21`, you might be working on processing or analyzing music data, such as parsing MIDI files or creating music representations.
#    - **Machine Learning & Deep Learning:**
#      - `scikit-learn` and `tensorflow` suggest that you might be training models, potentially for tasks like music genre classification, music generation, or other related tasks.
#    - **Data Handling:**
#      - `zipfile` and `os` are likely used for handling files, such as extracting datasets from ZIP archives.
#    - **Train-Test Split:**
#      - `train_test_split` from `sklearn` is used to divide your data into training and testing subsets.
#    - **JSON and Pickle:**
#      - These libraries are used for handling data, whether saving model parameters, loading data, or exchanging information between programs.
#    - **Visualization:**
#      - `matplotlib` is used to visualize results, such as plotting loss and accuracy during training.
#
# This code sets up an environment that could be used for a wide range of tasks related to music processing, machine learning, and deep learning. If you're working on a specific project, these tools will be integral to data handling, model creation, and analysis.

# %%
# !pip install scikit-learn tensorflow music21
import zipfile
import os
from sklearn.model_selection import train_test_split
import json
import music21 as m21
import numpy as np
from tensorflow import keras
import random
import pickle
import json
import matplotlib.pyplot as plt
# Out:
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.3.2)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.17.0)
# Requirement already satisfied: music21 in /usr/local/lib/python3.10/dist-packages (9.1.0)
# Requirement already satisfied: numpy<2.0,>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (71.0.4)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.64.1)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.17.0)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: chardet in /usr/local/lib/python3.10/dist-packages (from music21) (5.2.0)
# Requirement already satisfied: jsonpickle in /usr/local/lib/python3.10/dist-packages (from music21) (3.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from music21) (3.7.1)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.10/dist-packages (from music21) (10.3.0)
# Requirement already satisfied: webcolors>=1.5 in /usr/local/lib/python3.10/dist-packages (from music21) (24.6.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.44.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (13.7.1)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2024.7.4)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->music21) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->music21) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->music21) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->music21) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->music21) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->music21) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->music21) (2.8.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow) (0.1.2)

# %% [markdown]
# Unzip dataset and load it into a folder. We need to upload the dataset to google drive before that

# %%
zip_file_path = '/content/drive/MyDrive/deutschl.zip'
DATASET_PATH = '/content/drive/MyDrive/Deutschl_Folk_Songs_Dataset/'
from google.colab import drive
drive.mount('/content/drive')

# %%
import zipfile
import os

def extract_and_store_files_if_necessary(archive_path, output_directory):

    unzipped_file_paths = []  # List to store the paths of unzipped files

    # Check if the output directory exists and is empty
    if not os.path.exists(output_directory) or not os.listdir(output_directory):
        # Ensure the output directory exists (creates it if it doesn't)
        os.makedirs(output_directory, exist_ok=True)

        # Unzip the file
        with zipfile.ZipFile(archive_path, 'r') as zip_ref:
            zip_ref.extractall(output_directory)  # Extract files to the specified directory
            # Get the list of all unzipped files
            for file_name in zip_ref.namelist():
                unzipped_file_path = os.path.join(output_directory, file_name)
                unzipped_file_paths.append(unzipped_file_path)  # Save the file paths

        print(f"Files unzipped to {output_directory}")
    else:
        print(f"Directory '{output_directory}' already exists and is not empty. No files were unzipped.")

    return unzipped_file_paths

# %% [markdown]
# Purpose: The function extract_and_store_files_if_necessary is designed to extract files from a ZIP archive and store them in a specified output directory.
#
# Directory Check: It first checks whether the output directory exists and if it is empty. If the directory does not exist or is empty, it proceeds to unzip the files.
#
# Directory Creation: If the output directory does not exist, the function creates it.
#
# File Extraction: The function extracts all files from the specified ZIP archive into the output directory.
#
# File Tracking: After extraction, the function saves the paths of all the extracted files in a list, which it then returns.
#
# No Action if Directory Not Empty: If the output directory already exists and contains files, the function does not perform any extraction and notifies the user that no files were unzipped.
#
# Return Value: The function returns a list of file paths of the unzipped files.

# %%
# Call the function to unzip and save file paths if needed
extracted_files = extract_and_store_files_if_necessary(zip_file_path, DATASET_PATH)
# Out:
# Directory '/content/drive/MyDrive/Deutschl_Folk_Songs_Dataset/' already exists and is not empty. No files were unzipped.
# Extracted files: []

# %% [markdown]
# Purpose: The divide_tracks function splits a list of tracks into three subsets: training, validation, and testing.
#
# Ratio Validation: The function checks that the provided ratios for training, validation, and testing sum up to 1. This ensures a proper split of the dataset.
#
# Randomization: The tracks are shuffled randomly to ensure that the data is distributed without any bias. A fixed seed is used for reproducibility.
#
# Calculating Splits: The function calculates the number of tracks that should go into each of the three subsets based on the provided ratios.
#
# Dataset Splitting: The tracks are divided into three separate lists: training_tracks, validation_tracks, and testing_tracks, according to the calculated splits.
#
# Return Value: The function returns the three subsets: training_tracks, validation_tracks, and testing_tracks.

# %%
def divide_tracks(tracks, training_ratio=0.6, validation_ratio=0.2, testing_ratio=0.2):

    # Sanity check to make sure the ratios sum to 1
    assert training_ratio + validation_ratio + testing_ratio == 1.0, "Ratios must sum to 1"

    # Shuffle the tracks to ensure random distribution
    random.seed(42)  # For reproducibility
    random.shuffle(tracks)

    # Calculate the number of files for each split
    total_tracks = len(tracks)
    training_split = int(training_ratio * total_tracks)
    validation_split = int(validation_ratio * total_tracks)

    # Split the tracks into training, validation, and testing sets
    training_tracks = tracks[:training_split]
    validation_tracks = tracks[training_split:training_split + validation_split]
    testing_tracks = tracks[training_split + validation_split:]

    return training_tracks, validation_tracks, testing_tracks

# %% [markdown]
# Purpose: The load_kern function loads and parses all .krn (Kern) files from a specified root directory and its subdirectories.
#
# Directory Traversal: The function walks through the root directory and all its subdirectories to locate .krn files.
#
# File Filtering: It specifically looks for files with the .krn extension, which are Kern format music notation files.
#
# Parsing Files: For each .krn file found, the function uses music21 to parse the file into a music21 stream object.
#
# Data Collection: The parsed songs are stored in a list called parsed_songs.
#
# Output Information: The function prints out the total number of parsed songs once all files have been processed.
#
# Return Value: The function returns the list parsed_songs containing the parsed music21 stream objects of all .krn files found in the directory.

# %%
def load_kern(root_directory):

    parsed_songs = []
    for current_path, subdirectories, file_list in os.walk(root_directory):
        print(f"Inspecting directory: {current_path}")

        for filename in file_list:
            if filename.endswith(".krn"):
                song_path = os.path.join(current_path, filename)
                parsed_song = m21.converter.parse(song_path)
                parsed_songs.append(parsed_song)

    print(f"Total number of parsed songs: {len(parsed_songs)}")
    return parsed_songs

# %% [markdown]
# Purpose: The load_and_store_tracks function loads musical tracks from a specified directory, splits them into training, validation, and testing sets, and then saves these sets to disk.
#
# Loading Tracks: The function uses the load_kern function to load all .krn files (Kern format music notation files) from the specified data_path.
#
# Dataset Splitting: It divides the loaded tracks into training, validation, and testing sets based on the provided ratios (training_ratio, validation_ratio, and testing_ratio) using the divide_tracks function.
#
# Directory Creation: The function ensures that the specified output directory exists, creating it if necessary.
#
# Saving Data: The function saves the training, validation, and testing sets as pickle files in the output directory. The files are named training_tracks.pkl, validation_tracks.pkl, and testing_tracks.pkl.
#
# Output Information: It provides feedback by printing the sizes of each dataset split and confirms that the datasets have been successfully saved to the specified directory.
#
# Return Value: The function does not return a value but performs all operations and saves the results directly to disk.

# %%
def load_and_store_tracks(data_path, output_dir, training_ratio=0.6, validation_ratio=0.2, testing_ratio=0.2):

    # Step 1: Load all the tracks
    all_tracks = load_kern(data_path)

    # Step 2: Split the tracks into training, validation, and testing sets
    training_tracks, validation_tracks, testing_tracks = divide_tracks(all_tracks, training_ratio, validation_ratio, testing_ratio)
    print(f"Training set size: {len(training_tracks)}")
    print(f"Validation set size: {len(validation_tracks)}")
    print(f"Testing set size: {len(testing_tracks)}")

    # Step 3: Save the split datasets using pickle
    os.makedirs(output_dir, exist_ok=True)

    # Define file paths for the pickle files
    training_file_path = os.path.join(output_dir, 'training_tracks.pkl')
    validation_file_path = os.path.join(output_dir, 'validation_tracks.pkl')
    testing_file_path = os.path.join(output_dir, 'testing_tracks.pkl')

    # Save the lists using pickle
    with open(training_file_path, 'wb') as training_file:
        pickle.dump(training_tracks, training_file)

    with open(validation_file_path, 'wb') as validation_file:
        pickle.dump(validation_tracks, validation_file)

    with open(testing_file_path, 'wb') as testing_file:
        pickle.dump(testing_tracks, testing_file)

    print(f"Training, validation, and testing sets saved to {output_dir}")

# %%
import pickle
# location = '/content'
filename = 'targets.pkl'
with open(filename, 'wb') as file:
    pickle.dump(all_targets, file)
load_and_store_tracks(DATASET_PATH, output_dir)

# %% [markdown]
# Few constants being initialized

# %%
# File and data paths
COMBINED_TRACKS_PATH = "tracks_dataset_combined"
MAPPING_CONFIG_PATH = "mapping_config.json"
SEQUENCE_LEN = 64

# Allowed note durations in quarter lengths
PERMITTED_DURATIONS = [
    0.25,
    0.5,
    0.75,
    1.0,
    1.5,
    2.0,
    3.0,
    4.0
]

output_dir = '/content/drive/MyDrive/PickleFiles'

# Neural network configuration
LSTM_UNITS = [256]
LOSS_FUNC = "sparse_categorical_crossentropy"
LR = 0.001
NUM_NUM_EPOCHS = 50
BATCH_SZ = 64
DROPOUT_RATE_RATE = 0.2

# Paths for saving models
LSTM_SAVE_PATH = "lstm_model.h5"
GRU_SAVE_PATH = "gru_model.h5"
VANILLA_RNN_SAVE_PATH = "vanilla_rnn_model.h5"

# Directory for saving files
OUTPUT_DIR = "/content/savedFiles"

# %%
os.makedirs(OUTPUT_DIR, exist_ok=True)

# %% [markdown]
# Purpose: The contains_permitted_durations function checks if all notes and rests in a given musical track have durations that are within a specified list of permitted durations.
#
# Iterating Through Elements: The function iterates over every note and rest in the provided track_stream.
#
# Duration Check: For each musical element (note or rest), the function checks whether its duration (in quarter lengths) is included in the permitted_durations list.
#
# Validation Outcome:
#
# If any note or rest has a duration that is not in the permitted_durations list, the function immediately returns False, indicating that the track contains non-permitted durations.
# If all notes and rests have permitted durations, the function returns True.
# Return Value: The function returns a Boolean value: True if all durations are permitted, and False if any duration is not permitted.

# %%
def contains_permitted_durations(track_stream, permitted_durations):
    # Iterate over all notes and rests in the track stream
    for music_element in track_stream.flat.notesAndRests:
        # Check if the duration of the current note or rest is not in the list of permitted durations
        if music_element.duration.quarterLength not in permitted_durations:
            return False  # Return False if a non-permitted duration is found

    return True  # Return True if all durations are permitted

# %% [markdown]
# Purpose: The standardize_key_CMaj_AMin function transposes a musical track to either C major or A minor, depending on its current key, and optionally saves the transposed track to a file.
#
# Key Identification: The function identifies the key of the track by analyzing the first part and the first measure. If the key is not explicitly defined, it estimates the key using music21's key analysis feature.
#
# Interval Calculation:
#
# If the track is in a major key, the function calculates the interval needed to transpose the track to C major.
# If the track is in a minor key, the function calculates the interval needed to transpose the track to A minor.
# Transposition: The track is transposed by the calculated interval, effectively standardizing the key to either C major or A minor.
#
# Optional Saving:
#
# If an output directory and file name are provided, the function saves the transposed track as a MIDI file.
# It ensures that the output directory exists (creating it if necessary) before saving the file.
# Return Value: The function returns the transposed track, whether or not it is saved to a file.

# %%
def standardize_key_CMaj_AMin(track, output_dir=None, output_file_name=None):

    parts = track.getElementsByClass(m21.stream.Part)
    first_measure = parts[0].measure(1)
    key_signature = first_measure.keySignature


    if not isinstance(key_signature, m21.key.Key):
        key_signature = track.analyze("key")

    if key_signature.mode == "major":
        interval_to_c_major = m21.interval.Interval(key_signature.tonic, m21.pitch.Pitch("C"))
    elif key_signature.mode == "minor":
        interval_to_a_minor = m21.interval.Interval(key_signature.tonic, m21.pitch.Pitch("A"))
    else:
        raise ValueError("The key mode is neither major nor minor, which is unexpected.")

    transposed_track = track.transpose(interval_to_c_major if key_signature.mode == "major" else interval_to_a_minor)

    if output_dir and output_file_name:
        # Ensure the output directory exists
        os.makedirs(output_dir, exist_ok=True)
        output_file_path = os.path.join(output_dir, output_file_name)
        transposed_track.write('midi', fp=output_file_path)

    return transposed_track

# %% [markdown]
# Purpose: The tune_encoded function encodes a musical track into a sequence of symbols representing notes and rests, with the duration of each element encoded over a specified time interval.
#
# Element Encoding:
#
# Notes are converted to their corresponding MIDI numbers.
# Rests are represented by the symbol "r".
# Time Interval Handling:
#
# The duration of each note or rest is divided by the specified time_interval to determine how many intervals the element spans.
# The first interval of each element is encoded with the actual symbol (MIDI number or "r"), while subsequent intervals are encoded with an underscore ("_") to represent the continuation of the element.
# Sequence Construction:
#
# The encoded symbols are collected into a list, which is then converted into a space-separated string.
# Return Value: The function returns the encoded sequence as a single string, representing the entire track.

# %%
def tune_encoded(track, time_interval=0.25):

    encoded_sequence = []

    for element in track.flat.notesAndRests:

        if isinstance(element, m21.note.Note):
            symbol = element.pitch.midi

        elif isinstance(element, m21.note.Rest):
            symbol = "r"

        num_intervals = int(element.duration.quarterLength / time_interval)

        for interval in range(num_intervals):
            if interval == 0:
                encoded_sequence.append(symbol)
            else:
                encoded_sequence.append("_")

    encoded_sequence = " ".join(map(str, encoded_sequence))

    return encoded_sequence

# %% [markdown]
# Purpose: The prepare_data_split function processes a dataset of musical tracks, transposes them to a standard key, encodes them into a sequence, and saves the processed tracks to text files.
#
# Loading the Dataset: The function begins by loading a list of tracks from a pickle file specified by pickle_path.
#
# Processing Each Track:
#
# The function iterates over each track in the dataset.
# For each track, it checks whether all notes and rests have durations that are within the allowed permitted_durations. If not, the track is skipped.
# Key Standardization: Tracks with permitted durations are transposed to either C major or A minor using the standardize_key_CMaj_AMin function.
#
# Encoding: The transposed track is then encoded into a sequence of symbols using the tune_encoded function.
#
# Saving the Encoded Tracks:
#
# The encoded tracks are saved as text files in the specified output_dir.
# Each track is saved with a filename that includes its index in the dataset.
# Progress Reporting: The function prints progress messages, including the number of tracks processed, skipped, and saved.
#
# Completion Message: At the end of processing, the function prints a message indicating that the preprocessing is complete

# %%
def prepare_data_split(pickle_path, output_dir, permitted_durations):

    print(f"Loading dataset from {pickle_path}...")
    with open(pickle_path, "rb") as file:
        tracks = pickle.load(file)
        print(f"Loaded {len(tracks)} tracks from {pickle_path}.")

        for i, track in enumerate(tracks):
            print(f"Processing track {i + 1}/{len(tracks)}...")

            if not contains_permitted_durations(track, permitted_durations):
                print(f"Skipping track {i + 1}: Contains non-permitted durations.")
                continue

            track = standardize_key_CMaj_AMin(track)
            print(f"Track {i + 1} transposed to C major/A minor.")

            encoded_track = tune_encoded(track)
            print(f"Track {i + 1} encoded.")

            save_path = os.path.join(output_dir, f"track_{i}.txt")
            with open(save_path, "w") as fp:
                fp.write(encoded_track)
            print(f"Track {i + 1} saved to {save_path}.")

            if i % 10 == 0 and i > 0:
                print(f"Processed {i + 1} out of {len(tracks)} tracks.")

    print(f"Preprocessing for {pickle_path} completed.")

# %% [markdown]
# Purpose: The preprocess_pickled_datasets function processes and saves preprocessed versions of training, validation, and test datasets that are stored in pickle files.
#
# Directory Setup:
# *   The function first ensures that directories exist for saving the processed training, validation, and test datasets.
# *   Separate subdirectories are created within the specified save_directory for each dataset split (train, val, test).
# Processing Each Dataset Split:
#
# Training Data: The function loads the training dataset from train_pickle, processes it using prepare_data_split, and saves the results in the train subdirectory.
#
# Validation Data: The function loads the validation dataset from val_pickle, processes it, and saves the results in the val subdirectory.
# Test Data: The function loads the test dataset from test_pickle, processes it, and saves the results in the test subdirectory.
#
# Preprocessing Function: The prepare_data_split function is used to process each dataset. This involves loading the data, filtering tracks based on allowed durations, transposing tracks to a standard key, encoding them, and saving the encoded tracks as text files.
#
# Completion Message: After all datasets have been processed and saved, the function prints a message indicating that the preprocessing of all datasets has been completed.

# %%
def preprocess_pickled_datasets(train_pickle, val_pickle, test_pickle, save_directory, allowed_durations):

    # Ensure save directories exist for each dataset split
    train_save_dir = os.path.join(save_directory, "train")
    val_save_dir = os.path.join(save_directory, "val")
    test_save_dir = os.path.join(save_directory, "test")
    os.makedirs(train_save_dir, exist_ok=True)
    os.makedirs(val_save_dir, exist_ok=True)
    os.makedirs(test_save_dir, exist_ok=True)

    # Load and preprocess the training data
    print("Processing training dataset...")
    prepare_data_split(train_pickle, train_save_dir, allowed_durations)

    # Load and preprocess the validation data
    print("Processing validation dataset...")
    prepare_data_split(val_pickle, val_save_dir, allowed_durations)

    # Load and preprocess the test data
    print("Processing test dataset...")
    prepare_data_split(test_pickle, test_save_dir, allowed_durations)

    print("Preprocessing of all datasets completed.")

# %% [markdown]
# Get the tune from the file path

# %%
def read_tune(file_path):

    with open(file_path, "r") as fp:
        song = fp.read()
    return song

# %% [markdown]
# Purpose: The generate_merged_dataset function combines multiple tracks from a directory into a single dataset, with each track separated by a specified delimiter, and saves the merged dataset to a file.
#
# Delimiter Creation:
#
# The function creates a delimiter string based on the specified seq_length. This delimiter is used to separate tracks in the merged dataset.
# Merging Tracks:
#
# The function traverses the specified input_dir, loading each track file.
# Each loaded track is appended to the merged_tracks string, followed by the delimiter.
# File Loading:
#
# The function reads each track using the read_tune function, which is assumed to load the contents of the track file as a string.
# Final Formatting:
#
# After all tracks have been added to merged_tracks, the function removes any trailing delimiter to ensure a clean ending.
# Saving the Merged Dataset:
#
# The merged dataset is written to a file specified by output_file_path.
# The function confirms the successful save by printing a message.
# Return Value: The function returns the merged_tracks string, which contains all the tracks combined into one large dataset, separated by the specified delimiter.

# %%
def generate_merged_dataset(input_dir, output_file_path, seq_length):

    delimiter = "/ " * seq_length
    merged_tracks = ""

    print(f"Starting to merge tracks from directory: {input_dir}")
    print(f"Using sequence length of {seq_length} to create delimiters.")

    for dirpath, _, filenames in os.walk(input_dir):
        for filename in filenames:
            file_path = os.path.join(dirpath, filename)
            print(f"Loading track from file: {file_path}")
            track = read_tune(file_path)
            merged_tracks += track + " " + delimiter
            print(f"Added track from {filename} to merged dataset.")

    merged_tracks = merged_tracks.rstrip(" /")

    with open(output_file_path, "w") as fp:
        fp.write(merged_tracks)
    print(f"Merged dataset saved to: {output_file_path}")

    return merged_tracks

# %% [markdown]
# Purpose: The generate_mapping_from_tracks function creates a mapping from unique symbols found in the tracks to integer indices, and saves this mapping to a specified file.
#
# Splitting Tracks into Symbols:
#
# The function splits the entire tracks string into individual symbols, creating a list called track_symbols.
# Identifying Unique Symbols:
#
# The function identifies all unique symbols in the track_symbols list and stores them in unique_symbols.
# Mapping Symbols to Indices:
#
# The function creates a dictionary called symbol_to_index, where each unique symbol is mapped to a unique integer index.
# The index corresponds to the position of the symbol in the unique_symbols list.
# Saving the Mapping:
#
# The function saves the symbol_to_index dictionary as a JSON file to the specified mapping_output_path.
# A message is printed to confirm the successful saving of the mapping.
# Output Information:
#
# The function prints the size of the vocabulary (the number of unique symbols) and the mapping of each symbol to its corresponding index.

# %%
def generate_mapping_from_tracks(tracks, mapping_output_path):

    symbol_to_index = {}
    track_symbols = tracks.split()
    unique_symbols = list(set(track_symbols))
    print(f"Vocabulary size: {len(unique_symbols)} unique symbols identified.")
    for index, symbol in enumerate(unique_symbols):
        symbol_to_index[symbol] = index
        print(f"Mapping '{symbol}' to {index}")
    with open(mapping_output_path, "w") as fp:
        json.dump(symbol_to_index, fp, indent=4)
    print(f"Mapping saved to {mapping_output_path}")

# %% [markdown]
# Purpose: The tracks_to_int function converts a sequence of track symbols into a sequence of integers based on a pre-existing symbol-to-index mapping.
#
# Loading the Mapping:
#
# The function loads a mapping from symbols to integers from a JSON file specified by mapping_file_path.
# Splitting Tracks into Symbols:
#
# The function splits the entire tracks string into individual symbols, creating a list called track_symbols.
# Converting Symbols to Integers:
#
# For each symbol in the track_symbols list, the function looks up its corresponding integer in the symbol_to_index mapping.
# The function then appends this integer to the integer_tracks list.
# Output Information:
#
# The function prints messages to indicate progress, including when the mapping is loaded, how many symbols are being converted, and the conversion of each symbol to its corresponding integer.
# Return Value:
#
# The function returns integer_tracks, a list of integers that represent the converted track symbols.

# %%
def tracks_to_int(tracks, mapping_file_path):
    integer_tracks = []
    print(f"Loading mapping from {mapping_file_path}...")
    with open(mapping_file_path, "r") as fp:
        symbol_to_index = json.load(fp)
    print("Mapping loaded successfully.")
    track_symbols = tracks.split()
    print(f"Converting {len(track_symbols)} symbols to integers...")
    for symbol in track_symbols:
        integer_tracks.append(symbol_to_index[symbol])
        print(f"Symbol '{symbol}' converted to {symbol_to_index[symbol]}")

    print("Conversion completed successfully.")
    return integer_tracks

# %% [markdown]
# Purpose: The prepare_training_data_in_batches function generates batches of training data from a sequence of encoded tracks. This data is used to train a model, typically for sequence prediction tasks.
#
# Loading and Processing Tracks:
#
# The function reads a combined sequence of tracks from the file specified by combined_file_path.
# It converts the tracks into integers using a pre-existing mapping loaded from mapping_file_path.
# Determining Vocabulary Size:
#
# The function calculates the vocabulary size, which is the number of unique integer symbols in the converted tracks. This is used to one-hot encode the input sequences.
# Generating Batches:
#
# The function generates batches of input and target sequences in a loop, where:
# Inputs: Each input batch is a sequence of integers of length sequence_length.
# Targets: The target for each input sequence is the next integer in the sequence following the input sequence.
# The input sequences are one-hot encoded into categorical format using keras.utils.to_categorical, based on the vocabulary size.
# The function yields these batches of input and target sequences as arrays.
# Batch Size:
#
# The function creates batches of size batch_size. The loop iterates through the track data, creating input and target pairs until all possible sequences are generated.
# Yielding Data:
#
# Instead of returning the data all at once, the function uses yield to generate batches of data on-the-fly. This is particularly useful when working with large datasets that cannot fit into memory all at once.

# %%
import numpy as np
import keras
def prepare_training_data_in_batches(sequence_length, combined_file_path, mapping_file_path, batch_size):
    songs = read_tune(combined_file_path)
    int_songs = tracks_to_int(songs, mapping_file_path)
    vocabulary_size = len(set(int_songs))

    for i in range(0, len(int_songs) - sequence_length, batch_size):
        inputs_batch = []
        targets_batch = []
        for j in range(batch_size):
            if i + j + sequence_length >= len(int_songs):
                break
            inputs_batch.append(int_songs[i+j:i+j+sequence_length])
            targets_batch.append(int_songs[i+j+sequence_length])

        inputs_batch = keras.utils.to_categorical(inputs_batch, num_classes=vocabulary_size)
        targets_batch = np.array(targets_batch)

        yield inputs_batch, targets_batch

# %% [markdown]
# Preprocess and Generate mapping for trainn test and val

# %%
train_file_path = os.path.join(output_dir, 'train_songs.pkl')
val_file_path = os.path.join(output_dir, 'val_songs.pkl')
test_file_path = os.path.join(output_dir, 'test_songs.pkl')

preprocess_pickled_datasets(train_file_path, val_file_path,test_file_path,OUTPUT_DIR,PERMITTED_DURATIONS )

songs = generate_merged_dataset(OUTPUT_DIR, COMBINED_TRACKS_PATH, SEQUENCE_LEN)
generate_mapping_from_tracks(songs, MAPPING_CONFIG_PATH)
# Out:
# Streaming output truncated to the last 5000 lines.
# Added song from song_562.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1646.txt
# Added song from song_1646.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1086.txt
# Added song from song_1086.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_931.txt
# Added song from song_931.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_696.txt
# Added song from song_696.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_495.txt
# Added song from song_495.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_817.txt
# Added song from song_817.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_660.txt
# Added song from song_660.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_305.txt
# Added song from song_305.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_961.txt
# Added song from song_961.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2401.txt
# Added song from song_2401.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_3151.txt
# Added song from song_3151.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_339.txt
# Added song from song_339.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1586.txt
# Added song from song_1586.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_221.txt
# Added song from song_221.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1437.txt
# Added song from song_1437.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_183.txt
# Added song from song_183.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2116.txt
# Added song from song_2116.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2390.txt
# Added song from song_2390.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_558.txt
# Added song from song_558.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1709.txt
# Added song from song_1709.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_129.txt
# Added song from song_129.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_360.txt
# Added song from song_360.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2637.txt
# Added song from song_2637.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_890.txt
# Added song from song_890.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_195.txt
# Added song from song_195.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1573.txt
# Added song from song_1573.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1358.txt
# Added song from song_1358.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_3164.txt
# Added song from song_3164.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2208.txt
# Added song from song_2208.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2313.txt
# Added song from song_2313.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1597.txt
# Added song from song_1597.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_3135.txt
# Added song from song_3135.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_852.txt
# Added song from song_852.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_739.txt
# Added song from song_739.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1632.txt
# Added song from song_1632.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2416.txt
# Added song from song_2416.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1875.txt
# Added song from song_1875.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_233.txt
# Added song from song_233.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1800.txt
# Added song from song_1800.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2765.txt
# Added song from song_2765.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_3110.txt
# Added song from song_3110.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1149.txt
# Added song from song_1149.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1596.txt
# Added song from song_1596.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2417.txt
# Added song from song_2417.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_537.txt
# Added song from song_537.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_725.txt
# Added song from song_725.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_912.txt
# Added song from song_912.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_920.txt
# Added song from song_920.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_899.txt
# Added song from song_899.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2226.txt
# Added song from song_2226.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_18.txt
# Added song from song_18.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2666.txt
# Added song from song_2666.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1685.txt
# Added song from song_1685.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1534.txt
# Added song from song_1534.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1621.txt
# Added song from song_1621.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_207.txt
# Added song from song_207.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1861.txt
# Added song from song_1861.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_863.txt
# Added song from song_863.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1642.txt
# Added song from song_1642.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_916.txt
# Added song from song_916.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2046.txt
# Added song from song_2046.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2287.txt
# Added song from song_2287.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_3205.txt
# Added song from song_3205.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1049.txt
# Added song from song_1049.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_750.txt
# Added song from song_750.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1430.txt
# Added song from song_1430.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_3017.txt
# Added song from song_3017.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_3146.txt
# Added song from song_3146.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1364.txt
# Added song from song_1364.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1196.txt
# Added song from song_1196.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2956.txt
# Added song from song_2956.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2045.txt
# Added song from song_2045.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1440.txt
# Added song from song_1440.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1157.txt
# Added song from song_1157.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1655.txt
# Added song from song_1655.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1769.txt
# Added song from song_1769.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1370.txt
# Added song from song_1370.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_814.txt
# Added song from song_814.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_149.txt
# Added song from song_149.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_788.txt
# Added song from song_788.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_533.txt
# Added song from song_533.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2100.txt
# Added song from song_2100.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2341.txt
# Added song from song_2341.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_3046.txt
# Added song from song_3046.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_302.txt
# Added song from song_302.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_41.txt
# Added song from song_41.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1592.txt
# Added song from song_1592.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1898.txt
# Added song from song_1898.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1675.txt
# Added song from song_1675.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2929.txt
# Added song from song_2929.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2673.txt
# Added song from song_2673.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2181.txt
# Added song from song_2181.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1434.txt
# Added song from song_1434.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_514.txt
# Added song from song_514.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_504.txt
# Added song from song_504.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_701.txt
# Added song from song_701.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_218.txt
# Added song from song_218.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_204.txt
# Added song from song_204.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_921.txt
# Added song from song_921.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_3025.txt
# Added song from song_3025.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1471.txt
# Added song from song_1471.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_693.txt
# Added song from song_693.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_581.txt
# Added song from song_581.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_808.txt
# Added song from song_808.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1955.txt
# Added song from song_1955.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1777.txt
# Added song from song_1777.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_594.txt
# Added song from song_594.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1953.txt
# Added song from song_1953.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2602.txt
# Added song from song_2602.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_325.txt
# Added song from song_325.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1047.txt
# Added song from song_1047.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1109.txt
# Added song from song_1109.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_459.txt
# Added song from song_459.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_555.txt
# Added song from song_555.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_658.txt
# Added song from song_658.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1520.txt
# Added song from song_1520.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_521.txt
# Added song from song_521.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2811.txt
# Added song from song_2811.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_139.txt
# Added song from song_139.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1755.txt
# Added song from song_1755.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1982.txt
# Added song from song_1982.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1895.txt
# Added song from song_1895.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2979.txt
# Added song from song_2979.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2070.txt
# Added song from song_2070.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1203.txt
# Added song from song_1203.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_970.txt
# Added song from song_970.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2170.txt
# Added song from song_2170.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1981.txt
# Added song from song_1981.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1178.txt
# Added song from song_1178.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_758.txt
# Added song from song_758.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2140.txt
# Added song from song_2140.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2864.txt
# Added song from song_2864.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1811.txt
# Added song from song_1811.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1746.txt
# Added song from song_1746.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1320.txt
# Added song from song_1320.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_3076.txt
# Added song from song_3076.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2468.txt
# Added song from song_2468.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1391.txt
# Added song from song_1391.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_3021.txt
# Added song from song_3021.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2407.txt
# Added song from song_2407.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2200.txt
# Added song from song_2200.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_466.txt
# Added song from song_466.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_529.txt
# Added song from song_529.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_97.txt
# Added song from song_97.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_697.txt
# Added song from song_697.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1080.txt
# Added song from song_1080.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2168.txt
# Added song from song_2168.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_44.txt
# Added song from song_44.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_535.txt
# Added song from song_535.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1206.txt
# Added song from song_1206.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2612.txt
# Added song from song_2612.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2021.txt
# Added song from song_2021.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_352.txt
# Added song from song_352.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1236.txt
# Added song from song_1236.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2206.txt
# Added song from song_2206.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1933.txt
# Added song from song_1933.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1293.txt
# Added song from song_1293.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1470.txt
# Added song from song_1470.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2719.txt
# Added song from song_2719.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2967.txt
# Added song from song_2967.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2093.txt
# Added song from song_2093.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2686.txt
# Added song from song_2686.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1275.txt
# Added song from song_1275.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_285.txt
# Added song from song_285.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_3054.txt
# Added song from song_3054.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_55.txt
# Added song from song_55.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1758.txt
# Added song from song_1758.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_142.txt
# Added song from song_142.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1353.txt
# Added song from song_1353.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2922.txt
# Added song from song_2922.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2762.txt
# Added song from song_2762.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_981.txt
# Added song from song_981.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1894.txt
# Added song from song_1894.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_7.txt
# Added song from song_7.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2690.txt
# Added song from song_2690.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1496.txt
# Added song from song_1496.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_481.txt
# Added song from song_481.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2210.txt
# Added song from song_2210.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_148.txt
# Added song from song_148.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_623.txt
# Added song from song_623.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2310.txt
# Added song from song_2310.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1667.txt
# Added song from song_1667.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_614.txt
# Added song from song_614.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1624.txt
# Added song from song_1624.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_823.txt
# Added song from song_823.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1279.txt
# Added song from song_1279.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1472.txt
# Added song from song_1472.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2328.txt
# Added song from song_2328.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_762.txt
# Added song from song_762.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1609.txt
# Added song from song_1609.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2163.txt
# Added song from song_2163.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1485.txt
# Added song from song_1485.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_451.txt
# Added song from song_451.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1476.txt
# Added song from song_1476.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2623.txt
# Added song from song_2623.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1124.txt
# Added song from song_1124.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2973.txt
# Added song from song_2973.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_652.txt
# Added song from song_652.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2679.txt
# Added song from song_2679.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2683.txt
# Added song from song_2683.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2001.txt
# Added song from song_2001.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1737.txt
# Added song from song_1737.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_3207.txt
# Added song from song_3207.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2947.txt
# Added song from song_2947.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_88.txt
# Added song from song_88.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1262.txt
# Added song from song_1262.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2954.txt
# Added song from song_2954.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2074.txt
# Added song from song_2074.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2030.txt
# Added song from song_2030.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_3177.txt
# Added song from song_3177.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_46.txt
# Added song from song_46.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_79.txt
# Added song from song_79.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1889.txt
# Added song from song_1889.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2321.txt
# Added song from song_2321.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2364.txt
# Added song from song_2364.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1829.txt
# Added song from song_1829.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1239.txt
# Added song from song_1239.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1060.txt
# Added song from song_1060.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2513.txt
# Added song from song_2513.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2469.txt
# Added song from song_2469.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_384.txt
# Added song from song_384.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2675.txt
# Added song from song_2675.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_821.txt
# Added song from song_821.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_655.txt
# Added song from song_655.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1915.txt
# Added song from song_1915.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1348.txt
# Added song from song_1348.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2983.txt
# Added song from song_2983.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_94.txt
# Added song from song_94.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2004.txt
# Added song from song_2004.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2557.txt
# Added song from song_2557.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_550.txt
# Added song from song_550.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2885.txt
# Added song from song_2885.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1380.txt
# Added song from song_1380.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1011.txt
# Added song from song_1011.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1633.txt
# Added song from song_1633.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_3130.txt
# Added song from song_3130.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1012.txt
# Added song from song_1012.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_3103.txt
# Added song from song_3103.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2264.txt
# Added song from song_2264.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_3005.txt
# Added song from song_3005.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_332.txt
# Added song from song_332.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_146.txt
# Added song from song_146.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1201.txt
# Added song from song_1201.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_376.txt
# Added song from song_376.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_713.txt
# Added song from song_713.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_413.txt
# Added song from song_413.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2585.txt
# Added song from song_2585.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_3156.txt
# Added song from song_3156.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1180.txt
# Added song from song_1180.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_975.txt
# Added song from song_975.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1090.txt
# Added song from song_1090.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_100.txt
# Added song from song_100.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2492.txt
# Added song from song_2492.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2994.txt
# Added song from song_2994.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2772.txt
# Added song from song_2772.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1967.txt
# Added song from song_1967.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_3051.txt
# Added song from song_3051.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_447.txt
# Added song from song_447.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_392.txt
# Added song from song_392.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1188.txt
# Added song from song_1188.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2132.txt
# Added song from song_2132.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2488.txt
# Added song from song_2488.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2952.txt
# Added song from song_2952.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2332.txt
# Added song from song_2332.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2229.txt
# Added song from song_2229.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1669.txt
# Added song from song_1669.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_98.txt
# Added song from song_98.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_943.txt
# Added song from song_943.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_864.txt
# Added song from song_864.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1096.txt
# Added song from song_1096.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_378.txt
# Added song from song_378.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_474.txt
# Added song from song_474.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2121.txt
# Added song from song_2121.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2544.txt
# Added song from song_2544.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_881.txt
# Added song from song_881.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_643.txt
# Added song from song_643.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_198.txt
# Added song from song_198.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_830.txt
# Added song from song_830.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2442.txt
# Added song from song_2442.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1827.txt
# Added song from song_1827.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1880.txt
# Added song from song_1880.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2523.txt
# Added song from song_2523.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2550.txt
# Added song from song_2550.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1256.txt
# Added song from song_1256.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2712.txt
# Added song from song_2712.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_3075.txt
# Added song from song_3075.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_907.txt
# Added song from song_907.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2098.txt
# Added song from song_2098.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2621.txt
# Added song from song_2621.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_996.txt
# Added song from song_996.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_186.txt
# Added song from song_186.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_767.txt
# Added song from song_767.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_460.txt
# Added song from song_460.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_344.txt
# Added song from song_344.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_969.txt
# Added song from song_969.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1699.txt
# Added song from song_1699.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2969.txt
# Added song from song_2969.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_664.txt
# Added song from song_664.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1393.txt
# Added song from song_1393.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2320.txt
# Added song from song_2320.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1128.txt
# Added song from song_1128.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_721.txt
# Added song from song_721.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2153.txt
# Added song from song_2153.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_229.txt
# Added song from song_229.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_3042.txt
# Added song from song_3042.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1617.txt
# Added song from song_1617.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1368.txt
# Added song from song_1368.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2934.txt
# Added song from song_2934.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2857.txt
# Added song from song_2857.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_5.txt
# Added song from song_5.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_888.txt
# Added song from song_888.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1365.txt
# Added song from song_1365.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2988.txt
# Added song from song_2988.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2344.txt
# Added song from song_2344.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_23.txt
# Added song from song_23.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_161.txt
# Added song from song_161.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1139.txt
# Added song from song_1139.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_215.txt
# Added song from song_215.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1905.txt
# Added song from song_1905.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1730.txt
# Added song from song_1730.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1840.txt
# Added song from song_1840.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_363.txt
# Added song from song_363.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_3178.txt
# Added song from song_3178.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_51.txt
# Added song from song_51.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1784.txt
# Added song from song_1784.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_3061.txt
# Added song from song_3061.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_846.txt
# Added song from song_846.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_992.txt
# Added song from song_992.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1134.txt
# Added song from song_1134.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2233.txt
# Added song from song_2233.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2118.txt
# Added song from song_2118.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2347.txt
# Added song from song_2347.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_812.txt
# Added song from song_812.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1458.txt
# Added song from song_1458.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2033.txt
# Added song from song_2033.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_867.txt
# Added song from song_867.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2770.txt
# Added song from song_2770.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_3032.txt
# Added song from song_3032.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1306.txt
# Added song from song_1306.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1267.txt
# Added song from song_1267.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2860.txt
# Added song from song_2860.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_70.txt
# Added song from song_70.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2353.txt
# Added song from song_2353.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1798.txt
# Added song from song_1798.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_3174.txt
# Added song from song_3174.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2965.txt
# Added song from song_2965.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_3063.txt
# Added song from song_3063.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1015.txt
# Added song from song_1015.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_272.txt
# Added song from song_272.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2781.txt
# Added song from song_2781.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_3186.txt
# Added song from song_3186.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2094.txt
# Added song from song_2094.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1918.txt
# Added song from song_1918.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2604.txt
# Added song from song_2604.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2593.txt
# Added song from song_2593.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_942.txt
# Added song from song_942.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_194.txt
# Added song from song_194.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2547.txt
# Added song from song_2547.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1199.txt
# Added song from song_1199.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2757.txt
# Added song from song_2757.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_418.txt
# Added song from song_418.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_473.txt
# Added song from song_473.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1708.txt
# Added song from song_1708.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_469.txt
# Added song from song_469.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2813.txt
# Added song from song_2813.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_3115.txt
# Added song from song_3115.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1832.txt
# Added song from song_1832.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2465.txt
# Added song from song_2465.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1589.txt
# Added song from song_1589.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_168.txt
# Added song from song_168.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1225.txt
# Added song from song_1225.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2069.txt
# Added song from song_2069.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_246.txt
# Added song from song_246.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1431.txt
# Added song from song_1431.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2156.txt
# Added song from song_2156.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_432.txt
# Added song from song_432.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1712.txt
# Added song from song_1712.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_918.txt
# Added song from song_918.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2489.txt
# Added song from song_2489.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1566.txt
# Added song from song_1566.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2606.txt
# Added song from song_2606.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2060.txt
# Added song from song_2060.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1033.txt
# Added song from song_1033.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1919.txt
# Added song from song_1919.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2099.txt
# Added song from song_2099.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_759.txt
# Added song from song_759.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1581.txt
# Added song from song_1581.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2752.txt
# Added song from song_2752.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_487.txt
# Added song from song_487.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2183.txt
# Added song from song_2183.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_3092.txt
# Added song from song_3092.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1843.txt
# Added song from song_1843.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_980.txt
# Added song from song_980.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_286.txt
# Added song from song_286.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2841.txt
# Added song from song_2841.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_296.txt
# Added song from song_296.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_80.txt
# Added song from song_80.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1261.txt
# Added song from song_1261.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2345.txt
# Added song from song_2345.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1197.txt
# Added song from song_1197.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1782.txt
# Added song from song_1782.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1103.txt
# Added song from song_1103.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_993.txt
# Added song from song_993.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_226.txt
# Added song from song_226.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_3143.txt
# Added song from song_3143.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_92.txt
# Added song from song_92.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_144.txt
# Added song from song_144.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_3162.txt
# Added song from song_3162.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2292.txt
# Added song from song_2292.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_615.txt
# Added song from song_615.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2776.txt
# Added song from song_2776.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_317.txt
# Added song from song_317.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1318.txt
# Added song from song_1318.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_678.txt
# Added song from song_678.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_985.txt
# Added song from song_985.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_2608.txt
# Added song from song_2608.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_282.txt
# Added song from song_282.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1219.txt
# Added song from song_1219.txt to combined dataset.
# Loading song from file: /content/savedFiles/train/song_1859.txt
# Added song from song_1859.txt to combined dataset.
# ...
# Added song from song_349.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_1072.txt
# Added song from song_1072.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_242.txt
# Added song from song_242.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_903.txt
# Added song from song_903.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_357.txt
# Added song from song_357.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_543.txt
# Added song from song_543.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_228.txt
# Added song from song_228.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_968.txt
# Added song from song_968.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_827.txt
# Added song from song_827.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_952.txt
# Added song from song_952.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_1054.txt
# Added song from song_1054.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_405.txt
# Added song from song_405.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_988.txt
# Added song from song_988.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_172.txt
# Added song from song_172.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_728.txt
# Added song from song_728.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_997.txt
# Added song from song_997.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_883.txt
# Added song from song_883.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_659.txt
# Added song from song_659.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_875.txt
# Added song from song_875.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_525.txt
# Added song from song_525.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_700.txt
# Added song from song_700.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_540.txt
# Added song from song_540.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_578.txt
# Added song from song_578.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_12.txt
# Added song from song_12.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_924.txt
# Added song from song_924.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_457.txt
# Added song from song_457.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_779.txt
# Added song from song_779.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_343.txt
# Added song from song_343.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_223.txt
# Added song from song_223.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_22.txt
# Added song from song_22.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_747.txt
# Added song from song_747.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_672.txt
# Added song from song_672.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_15.txt
# Added song from song_15.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_383.txt
# Added song from song_383.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_964.txt
# Added song from song_964.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_145.txt
# Added song from song_145.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_82.txt
# Added song from song_82.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_936.txt
# Added song from song_936.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_24.txt
# Added song from song_24.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_1050.txt
# Added song from song_1050.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_190.txt
# Added song from song_190.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_799.txt
# Added song from song_799.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_618.txt
# Added song from song_618.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_475.txt
# Added song from song_475.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_424.txt
# Added song from song_424.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_891.txt
# Added song from song_891.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_690.txt
# Added song from song_690.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_10.txt
# Added song from song_10.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_1007.txt
# Added song from song_1007.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_604.txt
# Added song from song_604.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_351.txt
# Added song from song_351.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_1024.txt
# Added song from song_1024.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_396.txt
# Added song from song_396.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_263.txt
# Added song from song_263.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_132.txt
# Added song from song_132.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_284.txt
# Added song from song_284.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_295.txt
# Added song from song_295.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_445.txt
# Added song from song_445.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_166.txt
# Added song from song_166.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_866.txt
# Added song from song_866.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_462.txt
# Added song from song_462.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_689.txt
# Added song from song_689.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_120.txt
# Added song from song_120.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_369.txt
# Added song from song_369.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_56.txt
# Added song from song_56.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_637.txt
# Added song from song_637.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_579.txt
# Added song from song_579.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_219.txt
# Added song from song_219.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_52.txt
# Added song from song_52.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_608.txt
# Added song from song_608.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_416.txt
# Added song from song_416.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_806.txt
# Added song from song_806.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_327.txt
# Added song from song_327.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_624.txt
# Added song from song_624.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_107.txt
# Added song from song_107.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_959.txt
# Added song from song_959.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_1006.txt
# Added song from song_1006.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_176.txt
# Added song from song_176.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_731.txt
# Added song from song_731.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_878.txt
# Added song from song_878.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_185.txt
# Added song from song_185.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_341.txt
# Added song from song_341.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_790.txt
# Added song from song_790.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_945.txt
# Added song from song_945.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_722.txt
# Added song from song_722.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_666.txt
# Added song from song_666.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_425.txt
# Added song from song_425.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_379.txt
# Added song from song_379.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_947.txt
# Added song from song_947.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_736.txt
# Added song from song_736.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_518.txt
# Added song from song_518.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_564.txt
# Added song from song_564.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_674.txt
# Added song from song_674.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_979.txt
# Added song from song_979.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_324.txt
# Added song from song_324.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_438.txt
# Added song from song_438.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_489.txt
# Added song from song_489.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_999.txt
# Added song from song_999.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_616.txt
# Added song from song_616.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_126.txt
# Added song from song_126.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_276.txt
# Added song from song_276.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_613.txt
# Added song from song_613.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_503.txt
# Added song from song_503.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_619.txt
# Added song from song_619.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_595.txt
# Added song from song_595.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_534.txt
# Added song from song_534.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_734.txt
# Added song from song_734.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_468.txt
# Added song from song_468.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_839.txt
# Added song from song_839.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_978.txt
# Added song from song_978.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_102.txt
# Added song from song_102.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_519.txt
# Added song from song_519.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_109.txt
# Added song from song_109.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_1040.txt
# Added song from song_1040.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_409.txt
# Added song from song_409.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_816.txt
# Added song from song_816.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_346.txt
# Added song from song_346.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_288.txt
# Added song from song_288.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_726.txt
# Added song from song_726.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_264.txt
# Added song from song_264.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_553.txt
# Added song from song_553.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_1053.txt
# Added song from song_1053.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_65.txt
# Added song from song_65.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_800.txt
# Added song from song_800.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_75.txt
# Added song from song_75.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_382.txt
# Added song from song_382.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_522.txt
# Added song from song_522.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_582.txt
# Added song from song_582.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_743.txt
# Added song from song_743.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_523.txt
# Added song from song_523.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_815.txt
# Added song from song_815.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_235.txt
# Added song from song_235.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_960.txt
# Added song from song_960.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_669.txt
# Added song from song_669.txt to combined dataset.
# Loading song from file: /content/savedFiles/val/song_193.txt
# Added song from song_193.txt to combined dataset.
# Combined dataset saved to: file_dataset_combined
# Vocabulary size: 50 unique symbols identified.
# Mapping '55' to 0
# Mapping '63' to 1
# Mapping '77' to 2
# Mapping '81' to 3
# Mapping '41' to 4
# Mapping '84' to 5
# Mapping '47' to 6
# Mapping 'r' to 7
# Mapping '52' to 8
# Mapping '/' to 9
# Mapping '58' to 10
# Mapping '46' to 11
# Mapping '51' to 12
# Mapping '73' to 13
# Mapping '80' to 14
# Mapping '50' to 15
# Mapping '49' to 16
# Mapping '74' to 17
# Mapping '76' to 18
# Mapping '54' to 19
# Mapping '40' to 20
# Mapping '88' to 21
# Mapping '79' to 22
# Mapping '67' to 23
# Mapping '53' to 24
# Mapping '71' to 25
# Mapping '57' to 26
# Mapping '64' to 27
# Mapping '45' to 28
# Mapping '59' to 29
# Mapping '68' to 30
# Mapping '83' to 31
# Mapping '62' to 32
# Mapping '60' to 33
# Mapping '75' to 34
# Mapping '70' to 35
# Mapping '69' to 36
# Mapping '82' to 37
# Mapping '85' to 38
# Mapping '_' to 39
# Mapping '61' to 40
# Mapping '56' to 41
# Mapping '48' to 42
# Mapping '66' to 43
# Mapping '78' to 44
# Mapping '65' to 45
# Mapping '72' to 46
# Mapping '86' to 47
# Mapping '89' to 48
# Mapping '43' to 49
# Mapping saved to mapping.json

# %%
with open(MAPPING_CONFIG_PATH, 'r') as f:
    mapping = json.load(f)
OUTPUT_UNITS  = len(mapping)
print(OUTPUT_UNITS)
# Out:
# 50

# %% [markdown]
# Purpose: The create_rnn_model function builds and compiles a Recurrent Neural Network (RNN) model using TensorFlow/Keras. The model type can be LSTM, GRU, or SimpleRNN, depending on the input parameters.
#
# RNN Layer Selection:
#
# Based on the model_type parameter, the function selects and initializes the appropriate RNN layer (LSTM, GRU, or SimpleRNN) with the specified number of hidden units (hidden_units).
# Model Architecture:
#
# The function constructs the model architecture starting with an input layer.
# The selected RNN layer is added to the model.
# A dropout layer is included to reduce overfitting.
# The output layer uses a dense layer with a softmax activation function, making it suitable for classification tasks.
# Compilation:
#
# The model is compiled with the specified loss_function and learning_rate.
# The Adam optimizer is used for training, and accuracy is used as the evaluation metric.
# Model Summary:
#
# The function prints a summary of the model architecture, which includes details of each layer, the number of parameters, and the overall structure.
# Return Value:
#
# The function returns the compiled Keras model, ready for training.

# %%
import tensorflow as tf
from tensorflow import keras

def create_rnn_model(model_type, num_output_units, hidden_units, loss_function, learning_rate):


    # Select the appropriate RNN layer based on the model type
    if model_type == 'LSTM':
        rnn_layer = keras.layers.LSTM(hidden_units[0])
    elif model_type == 'GRU':
        rnn_layer = keras.layers.GRU(hidden_units[0])
    elif model_type == 'SimpleRNN':
        rnn_layer = keras.layers.SimpleRNN(hidden_units[0])
    else:
        raise ValueError("Invalid model_type. Choose from 'LSTM', 'GRU', or 'SimpleRNN'.")

    # Build the model architecture
    print(f"Building the {model_type} model with {len(hidden_units)} hidden layers...")
    input_layer = keras.layers.Input(shape=(None, num_output_units))
    x = rnn_layer(input_layer)
    x = keras.layers.Dropout(DROPOUT_RATE)(x)
    output_layer = keras.layers.Dense(num_output_units, activation="softmax")(x)

    model = keras.Model(inputs=input_layer, outputs=output_layer)

    # Compile the model with the specified loss function and learning rate
    model.compile(loss=loss_function,
                  optimizer=keras.optimizers.Adam(learning_rate=learning_rate),
                  metrics=["accuracy"])

    # Print the model summary
    model.summary()

    return model

# %% [markdown]
# data_generator
# Purpose: The data_generator function generates batches of input and target data for training a model. It yields data in small batches, which is particularly useful when working with large datasets that cannot be loaded into memory all at once.
#
# Shuffling Data: At the beginning of each epoch, the data is shuffled to ensure that the model does not learn patterns specific to the order of the data.
#
# Batch Creation:
#
# The function iterates through the data in chunks of size batch_size.
# For each chunk, it yields a batch of inputs and corresponding targets.
# Infinite Loop: The function runs in an infinite loop (while True:), continuously providing data batches until the training process is complete.
#
# train_rnn_model
# Purpose: The train_rnn_model function builds, trains, and saves an RNN model (LSTM, GRU, or SimpleRNN) using the data provided.
#
# Model Creation:
#
# The function calls create_rnn_model to build the RNN model based on the specified model_type (e.g., LSTM, GRU, or SimpleRNN), with given output_units and hidden_units.
# The model is compiled with the provided loss_function and learning_rate.
# Data Generation:
#
# The function uses data_generator to create a generator that yields batches of input and target data for training.
# It calculates steps_per_epoch, which is the number of batches per epoch.
# Training:
#
# The model is trained using the data generator over the specified number of epochs.
# Training progress and results are printed to the console.
# Model Saving:
#
# After training, the model is saved to a file named based on the model_type (e.g., "LSTM_model.h5").
# Return Value:
#
# The function returns the history object from the model.fit call, which contains details about the training process, including the loss and accuracy for each epoch.

# %%
import numpy as np
import tensorflow as tf

def data_generator(inputs, targets, batch_size):

    data_size = len(inputs)
    while True:
        # Shuffle the data at the beginning of each epoch
        indices = np.arange(data_size)
        np.random.shuffle(indices)
        inputs = inputs[indices]
        targets = targets[indices]

        for start in range(0, data_size, batch_size):
            end = min(start + batch_size, data_size)
            yield inputs[start:end], targets[start:end]

def train_rnn_model(model_type, output_units, hidden_units, loss_function, learning_rate, inputs, targets, epochs, batch_size):

    # Create the RNN model based on the specified type
    model = create_rnn_model(model_type, output_units, hidden_units, loss_function, learning_rate)

    # Create the data generator
    train_gen = data_generator(inputs, targets, batch_size)
    steps_per_epoch = len(inputs) // batch_size

    # Start training the model using the generator
    print(f"Starting {model_type} model training with data generator...")
    history = model.fit(train_gen, steps_per_epoch=steps_per_epoch, epochs=epochs)
    print(f"Training for {model_type} model completed.")

    # Save the trained model
    model_save_path = f"{model_type}_model.h5"
    model.save(model_save_path)
    print(f"Model saved to {model_save_path}.")

    return history

# %%
# Initialize lists to store all inputs and targets
all_inputs = []
all_targets = []
BATCH_SIZE_GENERATOR = 32
prepared_training_data = prepare_training_data_in_batches(SEQUENCE_LEN, COMBINED_FILE_PATH, MAPPING_CONFIG_PATH, BATCH_SZ_GENERATOR)

# %%
# Generate and save all batches
for inputs_batch, targets_batch in prepared_training_data:
    all_inputs.append(inputs_batch)
    all_targets.append(targets_batch)

# %%
import numpy as np
# Convert lists to NumPy arrays
inputs = np.concatenate(all_inputs, axis=0)

# %%
targets = np.concatenate(all_targets, axis=0)

# %%
import tensorflow as tf
history_lstm = None

# Set the default device to GPU
with tf.device('/GPU:0'):
  history_lstm = train_rnn_model('LSTM', OUTPUT_UNITS, LSTM_UNITS, LOSS_FUNC, LR, inputs, targets, NUM_EPOCHS, BATCH_SZ)

# %%
  # Train the GRU model
  history_gru = train_rnn_model('GRU', OUTPUT_UNITS, LSTM_UNITS, LOSS_FUNC, LR, all_inputs, all_targets, NUM_EPOCHS, BATCH_SZ)
  # Train the VanillaRNN model
  history_vanilla_rnn = train_rnn_model('SimpleRNN', OUTPUT_UNITS, LSTM_UNITS, LOSS_FUNC, LR,all_inputs, all_targets, NUM_EPOCHS, BATCH_SZ)

# %% [markdown]
# Plotting Performance

# %%
def plot_model_performance(histories, model_names):
    metrics = ['accuracy', 'loss', 'precision', 'recall']

    for metric in metrics:
        plt.figure(figsize=(10, 6))
        for history, model_name in zip(histories, model_names):
            plt.plot(history.history[metric], label=f'{model_name} {metric.capitalize()}')
        plt.title(f'Model {metric.capitalize()} Comparison')
        plt.xlabel('Epoch')
        plt.ylabel(metric.capitalize())
        plt.legend(loc='best')
        plt.grid(True)
        plt.show()

# %%
# Plot and compare model performance across metrics
plot_model_performance(
    histories=[history_lstm, history_gru, history_vanilla_rnn],
    model_names=['LSTM', 'GRU', 'SimpleRNN']
)
